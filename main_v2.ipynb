# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load the data
df = pd.read_csv('data/get_around_pricing_project.csv', index_col=0)

# Extract the features
X = df.drop('rental_price_per_day', axis=1)

# Extract the target column
y = df.loc[:, 'rental_price_per_day']

# Train / test split 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size = 0.2)

# Determine categorical and numerical features
numerical_features = X.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X.select_dtypes(include=['object', 'bool']).columns

# Numerical Transformer
numerical_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Categorical Transformer
categorical_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ("numerical_transformer", numerical_transformer, numerical_features),
        ("categorical_transformer", categorical_transformer, categorical_features)
    ]
)

# Create a pipeline for each model with preprocessor
pipelines = [
    Pipeline([('preprocessor', preprocessor), ('model', LinearRegression())]),
    Pipeline([('preprocessor', preprocessor), ('model', DecisionTreeRegressor())]),
    Pipeline([('preprocessor', preprocessor), ('model', RandomForestRegressor())]),
    Pipeline([('preprocessor', preprocessor), ('model', GradientBoostingRegressor())])
]

# Hyperparameters for each model
param_grids = [
    {},  # Linear Regression
    {'model__max_depth': [2, 5, 10, 20], 'model__min_samples_split': [2, 5, 10]},  # Decision Tree Regressor
    {'model__n_estimators': [100, 200, 500], 'model__max_depth': [2, 5, 10, 20], 'model__min_samples_split': [2, 5, 10]},  # Random Forest Regressor
    {'model__n_estimators': [100, 200, 500], 'model__learning_rate': [0.01, 0.1, 0.2]},  # Gradient Boosting Regressor
]

best_estimators = []

for pipe, param_grid in zip(pipelines, param_grids):
    grid = GridSearchCV(pipe, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)
    grid.fit(X_train, y_train)
    best_estimators.append(grid.best_estimator_)
    print(grid.best_params_)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {}
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'model__max_depth': 10, 'model__min_samples_split': 10}
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'model__max_depth': 20, 'model__min_samples_split': 5, 'model__n_estimators': 500}
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/pryda/.pyenv/versions/3.11.0 /envs/bloc_5/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'model__learning_rate': 0.1, 'model__n_estimators': 500}

# %%
# Create an empty list to store the model results
model_results = []

# Evaluate the models using R2 score and Mean Squared Error, and save the results
for i, model in enumerate(best_estimators):
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    mse_train = mean_squared_error(y_train, y_pred_train)
    mse_test = mean_squared_error(y_test, y_pred_test)
    
    r2_train = r2_score(y_train, y_pred_train)
    r2_test = r2_score(y_test, y_pred_test)
    print(f"Model {i+1}")
    print(best_estimators[i].get_params())
          
    model_results.append({
        "model": f"Model {i+1}",
        "best_params": best_estimators[i].get_params(),
        "mse_train": mse_train,
        "mse_test": mse_test,
        "r2_train": r2_train,
        "r2_test": r2_test
    })

# Convert the list of model results into a DataFrame
model_results_df = pd.DataFrame(model_results)

# Print the DataFrame
print(model_results_df)
# Out:
# Model 1
# {'memory': None, 'steps': [('preprocessor', ColumnTransformer(transformers=[('numerical_transformer',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['mileage', 'engine_power'], dtype='object')),
#                                 ('categorical_transformer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'))]),
#                                  Index(['model_key', 'fuel', 'paint_color', 'car_type',
#        'private_parking_available', 'has_gps', 'has_air_conditioning',
#        'automatic_car', 'has_getaround_connect', 'has_speed_regulator',
#        'winter_tires'],
#       dtype='object'))])), ('model', LinearRegression())], 'verbose': False, 'preprocessor': ColumnTransformer(transformers=[('numerical_transformer',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['mileage', 'engine_power'], dtype='object')),
#                                 ('categorical_transformer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'))]),
#                                  Index(['model_key', 'fuel', 'paint_color', 'car_type',
#        'private_parking_available', 'has_gps', 'has_air_conditioning',
#        'automatic_car', 'has_getaround_connect', 'has_speed_regulator',
#        'winter_tires'],
#       dtype='object'))]), 'model': LinearRegression(), 'preprocessor__n_jobs': None, 'preprocessor__remainder': 'drop', 'preprocessor__sparse_threshold': 0.3, 'preprocessor__transformer_weights': None, 'preprocessor__transformers': [('numerical_transformer', Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler())]), Index(['mileage', 'engine_power'], dtype='object')), ('categorical_transformer', Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OneHotEncoder(drop='first', handle_unknown='ignore'))]), Index(['model_key', 'fuel', 'paint_color', 'car_type',
#        'private_parking_available', 'has_gps', 'has_air_conditioning',
#        'automatic_car', 'has_getaround_connect', 'has_speed_regulator',
#        'winter_tires'],
#       dtype='object'))], 'preprocessor__verbose': False, 'preprocessor__verbose_feature_names_out': True, 'preprocessor__numerical_transformer': Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler())]), 'preprocessor__categorical_transformer': Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OneHotEncoder(drop='first', handle_unknown='ignore'))]), 'preprocessor__numerical_transformer__memory': None, 'preprocessor__numerical_transformer__steps': [('imputer', SimpleImputer()), ('scaler', StandardScaler())], 'preprocessor__numerical_transformer__verbose': False, 'preprocessor__numerical_transformer__imputer': SimpleImputer(), 'preprocessor__numerical_transformer__scaler': StandardScaler(), 'preprocessor__numerical_transformer__imputer__add_indicator': False, 'preprocessor__numerical_transformer__imputer__copy': True, 'preprocessor__numerical_transformer__imputer__fill_value': None, 'preprocessor__numerical_transformer__imputer__keep_empty_features': False, 'preprocessor__numerical_transformer__imputer__missing_values': nan, 'preprocessor__numerical_transformer__imputer__strategy': 'mean', 'preprocessor__numerical_transformer__imputer__verbose': 'deprecated', 'preprocessor__numerical_transformer__scaler__copy': True, 'preprocessor__numerical_transformer__scaler__with_mean': True, 'preprocessor__numerical_transformer__scaler__with_std': True, 'preprocessor__categorical_transformer__memory': None, 'preprocessor__categorical_transformer__steps': [('imputer', SimpleImputer(strategy='most_frequent')), ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore'))], 'preprocessor__categorical_transformer__verbose': False, 'preprocessor__categorical_transformer__imputer': SimpleImputer(strategy='most_frequent'), 'preprocessor__categorical_transformer__encoder': OneHotEncoder(drop='first', handle_unknown='ignore'), 'preprocessor__categorical_transformer__imputer__add_indicator': False, 'preprocessor__categorical_transformer__imputer__copy': True, 'preprocessor__categorical_transformer__imputer__fill_value': None, 'preprocessor__categorical_transformer__imputer__keep_empty_features': False, 'preprocessor__categorical_transformer__imputer__missing_values': nan, 'preprocessor__categorical_transformer__imputer__strategy': 'most_frequent', 'preprocessor__categorical_transformer__imputer__verbose': 'deprecated', 'preprocessor__categorical_transformer__encoder__categories': 'auto', 'preprocessor__categorical_transformer__encoder__drop': 'first', 'preprocessor__categorical_transformer__encoder__dtype': <class 'numpy.float64'>, 'preprocessor__categorical_transformer__encoder__handle_unknown': 'ignore', 'preprocessor__categorical_transformer__encoder__max_categories': None, 'preprocessor__categorical_transformer__encoder__min_frequency': None, 'preprocessor__categorical_transformer__encoder__sparse': 'deprecated', 'preprocessor__categorical_transformer__encoder__sparse_output': True, 'model__copy_X': True, 'model__fit_intercept': True, 'model__n_jobs': None, 'model__positive': False}
# Model 2
# {'memory': None, 'steps': [('preprocessor', ColumnTransformer(transformers=[('numerical_transformer',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['mileage', 'engine_power'], dtype='object')),
#                                 ('categorical_transformer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'))]),
#                                  Index(['model_key', 'fuel', 'paint_color', 'car_type',
#        'private_parking_available', 'has_gps', 'has_air_conditioning',
#        'automatic_car', 'has_getaround_connect', 'has_speed_regulator',
#        'winter_tires'],
#       dtype='object'))])), ('model', DecisionTreeRegressor(max_depth=10, min_samples_split=10))], 'verbose': False, 'preprocessor': ColumnTransformer(transformers=[('numerical_transformer',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['mileage', 'engine_power'], dtype='object')),
#                                 ('categorical_transformer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'))]),
#                                  Index(['model_key', 'fuel', 'paint_color', 'car_type',
#        'private_parking_available', 'has_gps', 'has_air_conditioning',
#        'automatic_car', 'has_getaround_connect', 'has_speed_regulator',
#        'winter_tires'],
#       dtype='object'))]), 'model': DecisionTreeRegressor(max_depth=10, min_samples_split=10), 'preprocessor__n_jobs': None, 'preprocessor__remainder': 'drop', 'preprocessor__sparse_threshold': 0.3, 'preprocessor__transformer_weights': None, 'preprocessor__transformers': [('numerical_transformer', Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler())]), Index(['mileage', 'engine_power'], dtype='object')), ('categorical_transformer', Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OneHotEncoder(drop='first', handle_unknown='ignore'))]), Index(['model_key', 'fuel', 'paint_color', 'car_type',
#        'private_parking_available', 'has_gps', 'has_air_conditioning',
#        'automatic_car', 'has_getaround_connect', 'has_speed_regulator',
#        'winter_tires'],
#       dtype='object'))], 'preprocessor__verbose': False, 'preprocessor__verbose_feature_names_out': True, 'preprocessor__numerical_transformer': Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler())]), 'preprocessor__categorical_transformer': Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OneHotEncoder(drop='first', handle_unknown='ignore'))]), 'preprocessor__numerical_transformer__memory': None, 'preprocessor__numerical_transformer__steps': [('imputer', SimpleImputer()), ('scaler', StandardScaler())], 'preprocessor__numerical_transformer__verbose': False, 'preprocessor__numerical_transformer__imputer': SimpleImputer(), 'preprocessor__numerical_transformer__scaler': StandardScaler(), 'preprocessor__numerical_transformer__imputer__add_indicator': False, 'preprocessor__numerical_transformer__imputer__copy': True, 'preprocessor__numerical_transformer__imputer__fill_value': None, 'preprocessor__numerical_transformer__imputer__keep_empty_features': False, 'preprocessor__numerical_transformer__imputer__missing_values': nan, 'preprocessor__numerical_transformer__imputer__strategy': 'mean', 'preprocessor__numerical_transformer__imputer__verbose': 'deprecated', 'preprocessor__numerical_transformer__scaler__copy': True, 'preprocessor__numerical_transformer__scaler__with_mean': True, 'preprocessor__numerical_transformer__scaler__with_std': True, 'preprocessor__categorical_transformer__memory': None, 'preprocessor__categorical_transformer__steps': [('imputer', SimpleImputer(strategy='most_frequent')), ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore'))], 'preprocessor__categorical_transformer__verbose': False, 'preprocessor__categorical_transformer__imputer': SimpleImputer(strategy='most_frequent'), 'preprocessor__categorical_transformer__encoder': OneHotEncoder(drop='first', handle_unknown='ignore'), 'preprocessor__categorical_transformer__imputer__add_indicator': False, 'preprocessor__categorical_transformer__imputer__copy': True, 'preprocessor__categorical_transformer__imputer__fill_value': None, 'preprocessor__categorical_transformer__imputer__keep_empty_features': False, 'preprocessor__categorical_transformer__imputer__missing_values': nan, 'preprocessor__categorical_transformer__imputer__strategy': 'most_frequent', 'preprocessor__categorical_transformer__imputer__verbose': 'deprecated', 'preprocessor__categorical_transformer__encoder__categories': 'auto', 'preprocessor__categorical_transformer__encoder__drop': 'first', 'preprocessor__categorical_transformer__encoder__dtype': <class 'numpy.float64'>, 'preprocessor__categorical_transformer__encoder__handle_unknown': 'ignore', 'preprocessor__categorical_transformer__encoder__max_categories': None, 'preprocessor__categorical_transformer__encoder__min_frequency': None, 'preprocessor__categorical_transformer__encoder__sparse': 'deprecated', 'preprocessor__categorical_transformer__encoder__sparse_output': True, 'model__ccp_alpha': 0.0, 'model__criterion': 'squared_error', 'model__max_depth': 10, 'model__max_features': None, 'model__max_leaf_nodes': None, 'model__min_impurity_decrease': 0.0, 'model__min_samples_leaf': 1, 'model__min_samples_split': 10, 'model__min_weight_fraction_leaf': 0.0, 'model__random_state': None, 'model__splitter': 'best'}
# Model 3
# {'memory': None, 'steps': [('preprocessor', ColumnTransformer(transformers=[('numerical_transformer',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['mileage', 'engine_power'], dtype='object')),
#                                 ('categorical_transformer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'))]),
#                                  Index(['model_key', 'fuel', 'paint_color', 'car_type',
#        'private_parking_available', 'has_gps', 'has_air_conditioning',
#        'automatic_car', 'has_getaround_connect', 'has_speed_regulator',
#        'winter_tires'],
#       dtype='object'))])), ('model', RandomForestRegressor(max_depth=20, min_samples_split=5, n_estimators=500))], 'verbose': False, 'preprocessor': ColumnTransformer(transformers=[('numerical_transformer',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['mileage', 'engine_power'], dtype='object')),
#                                 ('categorical_transformer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'))]),
#                                  Index(['model_key', 'fuel', 'paint_color', 'car_type',
#        'private_parking_available', 'has_gps', 'has_air_conditioning',
#        'automatic_car', 'has_getaround_connect', 'has_speed_regulator',
#        'winter_tires'],
#       dtype='object'))]), 'model': RandomForestRegressor(max_depth=20, min_samples_split=5, n_estimators=500), 'preprocessor__n_jobs': None, 'preprocessor__remainder': 'drop', 'preprocessor__sparse_threshold': 0.3, 'preprocessor__transformer_weights': None, 'preprocessor__transformers': [('numerical_transformer', Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler())]), Index(['mileage', 'engine_power'], dtype='object')), ('categorical_transformer', Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OneHotEncoder(drop='first', handle_unknown='ignore'))]), Index(['model_key', 'fuel', 'paint_color', 'car_type',
#        'private_parking_available', 'has_gps', 'has_air_conditioning',
#        'automatic_car', 'has_getaround_connect', 'has_speed_regulator',
#        'winter_tires'],
#       dtype='object'))], 'preprocessor__verbose': False, 'preprocessor__verbose_feature_names_out': True, 'preprocessor__numerical_transformer': Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler())]), 'preprocessor__categorical_transformer': Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OneHotEncoder(drop='first', handle_unknown='ignore'))]), 'preprocessor__numerical_transformer__memory': None, 'preprocessor__numerical_transformer__steps': [('imputer', SimpleImputer()), ('scaler', StandardScaler())], 'preprocessor__numerical_transformer__verbose': False, 'preprocessor__numerical_transformer__imputer': SimpleImputer(), 'preprocessor__numerical_transformer__scaler': StandardScaler(), 'preprocessor__numerical_transformer__imputer__add_indicator': False, 'preprocessor__numerical_transformer__imputer__copy': True, 'preprocessor__numerical_transformer__imputer__fill_value': None, 'preprocessor__numerical_transformer__imputer__keep_empty_features': False, 'preprocessor__numerical_transformer__imputer__missing_values': nan, 'preprocessor__numerical_transformer__imputer__strategy': 'mean', 'preprocessor__numerical_transformer__imputer__verbose': 'deprecated', 'preprocessor__numerical_transformer__scaler__copy': True, 'preprocessor__numerical_transformer__scaler__with_mean': True, 'preprocessor__numerical_transformer__scaler__with_std': True, 'preprocessor__categorical_transformer__memory': None, 'preprocessor__categorical_transformer__steps': [('imputer', SimpleImputer(strategy='most_frequent')), ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore'))], 'preprocessor__categorical_transformer__verbose': False, 'preprocessor__categorical_transformer__imputer': SimpleImputer(strategy='most_frequent'), 'preprocessor__categorical_transformer__encoder': OneHotEncoder(drop='first', handle_unknown='ignore'), 'preprocessor__categorical_transformer__imputer__add_indicator': False, 'preprocessor__categorical_transformer__imputer__copy': True, 'preprocessor__categorical_transformer__imputer__fill_value': None, 'preprocessor__categorical_transformer__imputer__keep_empty_features': False, 'preprocessor__categorical_transformer__imputer__missing_values': nan, 'preprocessor__categorical_transformer__imputer__strategy': 'most_frequent', 'preprocessor__categorical_transformer__imputer__verbose': 'deprecated', 'preprocessor__categorical_transformer__encoder__categories': 'auto', 'preprocessor__categorical_transformer__encoder__drop': 'first', 'preprocessor__categorical_transformer__encoder__dtype': <class 'numpy.float64'>, 'preprocessor__categorical_transformer__encoder__handle_unknown': 'ignore', 'preprocessor__categorical_transformer__encoder__max_categories': None, 'preprocessor__categorical_transformer__encoder__min_frequency': None, 'preprocessor__categorical_transformer__encoder__sparse': 'deprecated', 'preprocessor__categorical_transformer__encoder__sparse_output': True, 'model__bootstrap': True, 'model__ccp_alpha': 0.0, 'model__criterion': 'squared_error', 'model__max_depth': 20, 'model__max_features': 1.0, 'model__max_leaf_nodes': None, 'model__max_samples': None, 'model__min_impurity_decrease': 0.0, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__min_weight_fraction_leaf': 0.0, 'model__n_estimators': 500, 'model__n_jobs': None, 'model__oob_score': False, 'model__random_state': None, 'model__verbose': 0, 'model__warm_start': False}
# Model 4
# {'memory': None, 'steps': [('preprocessor', ColumnTransformer(transformers=[('numerical_transformer',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['mileage', 'engine_power'], dtype='object')),
#                                 ('categorical_transformer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'))]),
#                                  Index(['model_key', 'fuel', 'paint_color', 'car_type',
#        'private_parking_available', 'has_gps', 'has_air_conditioning',
#        'automatic_car', 'has_getaround_connect', 'has_speed_regulator',
#        'winter_tires'],
#       dtype='object'))])), ('model', GradientBoostingRegressor(n_estimators=500))], 'verbose': False, 'preprocessor': ColumnTransformer(transformers=[('numerical_transformer',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['mileage', 'engine_power'], dtype='object')),
#                                 ('categorical_transformer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'))]),
#                                  Index(['model_key', 'fuel', 'paint_color', 'car_type',
#        'private_parking_available', 'has_gps', 'has_air_conditioning',
#        'automatic_car', 'has_getaround_connect', 'has_speed_regulator',
#        'winter_tires'],
#       dtype='object'))]), 'model': GradientBoostingRegressor(n_estimators=500), 'preprocessor__n_jobs': None, 'preprocessor__remainder': 'drop', 'preprocessor__sparse_threshold': 0.3, 'preprocessor__transformer_weights': None, 'preprocessor__transformers': [('numerical_transformer', Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler())]), Index(['mileage', 'engine_power'], dtype='object')), ('categorical_transformer', Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OneHotEncoder(drop='first', handle_unknown='ignore'))]), Index(['model_key', 'fuel', 'paint_color', 'car_type',
#        'private_parking_available', 'has_gps', 'has_air_conditioning',
#        'automatic_car', 'has_getaround_connect', 'has_speed_regulator',
#        'winter_tires'],
#       dtype='object'))], 'preprocessor__verbose': False, 'preprocessor__verbose_feature_names_out': True, 'preprocessor__numerical_transformer': Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler())]), 'preprocessor__categorical_transformer': Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OneHotEncoder(drop='first', handle_unknown='ignore'))]), 'preprocessor__numerical_transformer__memory': None, 'preprocessor__numerical_transformer__steps': [('imputer', SimpleImputer()), ('scaler', StandardScaler())], 'preprocessor__numerical_transformer__verbose': False, 'preprocessor__numerical_transformer__imputer': SimpleImputer(), 'preprocessor__numerical_transformer__scaler': StandardScaler(), 'preprocessor__numerical_transformer__imputer__add_indicator': False, 'preprocessor__numerical_transformer__imputer__copy': True, 'preprocessor__numerical_transformer__imputer__fill_value': None, 'preprocessor__numerical_transformer__imputer__keep_empty_features': False, 'preprocessor__numerical_transformer__imputer__missing_values': nan, 'preprocessor__numerical_transformer__imputer__strategy': 'mean', 'preprocessor__numerical_transformer__imputer__verbose': 'deprecated', 'preprocessor__numerical_transformer__scaler__copy': True, 'preprocessor__numerical_transformer__scaler__with_mean': True, 'preprocessor__numerical_transformer__scaler__with_std': True, 'preprocessor__categorical_transformer__memory': None, 'preprocessor__categorical_transformer__steps': [('imputer', SimpleImputer(strategy='most_frequent')), ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore'))], 'preprocessor__categorical_transformer__verbose': False, 'preprocessor__categorical_transformer__imputer': SimpleImputer(strategy='most_frequent'), 'preprocessor__categorical_transformer__encoder': OneHotEncoder(drop='first', handle_unknown='ignore'), 'preprocessor__categorical_transformer__imputer__add_indicator': False, 'preprocessor__categorical_transformer__imputer__copy': True, 'preprocessor__categorical_transformer__imputer__fill_value': None, 'preprocessor__categorical_transformer__imputer__keep_empty_features': False, 'preprocessor__categorical_transformer__imputer__missing_values': nan, 'preprocessor__categorical_transformer__imputer__strategy': 'most_frequent', 'preprocessor__categorical_transformer__imputer__verbose': 'deprecated', 'preprocessor__categorical_transformer__encoder__categories': 'auto', 'preprocessor__categorical_transformer__encoder__drop': 'first', 'preprocessor__categorical_transformer__encoder__dtype': <class 'numpy.float64'>, 'preprocessor__categorical_transformer__encoder__handle_unknown': 'ignore', 'preprocessor__categorical_transformer__encoder__max_categories': None, 'preprocessor__categorical_transformer__encoder__min_frequency': None, 'preprocessor__categorical_transformer__encoder__sparse': 'deprecated', 'preprocessor__categorical_transformer__encoder__sparse_output': True, 'model__alpha': 0.9, 'model__ccp_alpha': 0.0, 'model__criterion': 'friedman_mse', 'model__init': None, 'model__learning_rate': 0.1, 'model__loss': 'squared_error', 'model__max_depth': 3, 'model__max_features': None, 'model__max_leaf_nodes': None, 'model__min_impurity_decrease': 0.0, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__min_weight_fraction_leaf': 0.0, 'model__n_estimators': 500, 'model__n_iter_no_change': None, 'model__random_state': None, 'model__subsample': 1.0, 'model__tol': 0.0001, 'model__validation_fraction': 0.1, 'model__verbose': 0, 'model__warm_start': False}
#      model                                        best_params   mse_train
# 0  Model 1  {'memory': None, 'steps': [('preprocessor', Co...  327.406188  \
# 1  Model 2  {'memory': None, 'steps': [('preprocessor', Co...  164.246948
# 2  Model 3  {'memory': None, 'steps': [('preprocessor', Co...   69.584050
# 3  Model 4  {'memory': None, 'steps': [('preprocessor', Co...  145.657256
#
#      mse_test  r2_train   r2_test
# 0  322.585498  0.714010  0.693716
# 1  415.680552  0.856530  0.605326
# 2  280.062220  0.939218  0.734090
# 3  281.261745  0.872768  0.732952
